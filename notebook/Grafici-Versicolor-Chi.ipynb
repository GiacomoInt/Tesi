# %% [markdown]
# ### Codice

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def grafico(path):

    coppie = lettura_log(path)

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %%
def tabella(path):

    coppie = lettura_log(path)
    
    print ("N_ITER        RMSE_DISTANCE")
    for i in coppie:
        print ("{:<14}{:<11}".format(*i))

# %% [markdown]
# # Versicolor

# %%
grafico("../log/Versicolor-Chi/c1_sigma01_penalization01.log")
tabella("../log/Versicolor-Chi/c1_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2823457747691782
# 200           0.30322909386975805
# 300           0.5000033644826967
# 400           0.5000031162225926
# 500           0.30278425410549753
# 600           0.2963311700225255
# 700           0.2871462558156202
# 800           0.2837124643650095
# 900           0.2773552737742753
# 1000          0.2538033718860885
# 1100          0.23008236947113844
# 1200          0.8246210956329688
# 1300          0.8246210956329688
# 1400          0.5000041686986224
# 1500          0.5000041687841691

# %%
grafico("../log/Versicolor-Chi/c1_sigma01_penalization10.log")
tabella("../log/Versicolor-Chi/c1_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.20553347918484058
# 200           0.2792778165739056
# 300           0.32928233395008444
# 400           0.5000012445367746
# 500           0.5000012165782387
# 600           0.5000011494952935
# 700           0.5000012376059325
# 800           0.5000011701367828
# 900           0.5000011124873399
# 1000          0.5000011035110777
# 1100          0.5000011898172639
# 1200          0.5000011412639719
# 1300          0.5000011851886074
# 1400          0.5000011328333176
# 1500          0.5000011333241727

# %%
grafico("../log/Versicolor-Chi/c1_sigma01_penalization100.log")
tabella("../log/Versicolor-Chi/c1_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1969670177996133
# 200           0.2834251755388655
# 300           0.5000010990548964
# 400           0.5000011164957199
# 500           0.5000011627039511
# 600           0.5000011434010303
# 700           0.5000010479620444
# 800           0.5000009656977578
# 900           0.5000010792478604
# 1000          0.5000011332733043
# 1100          0.5000011252784817
# 1200          0.5000011312262894
# 1300          0.5000011278223148
# 1400          0.5000010324245069
# 1500          0.5000010348855305

# %%
grafico("../log/Versicolor-Chi/c1_sigma05_penalization01.log")
tabella("../log/Versicolor-Chi/c1_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           8.077908698862162e-08
# 200           0.07943927663629768
# 300           0.11759372509300463
# 400           0.18564368849753396
# 500           0.20361736958805118
# 600           0.2025772656278247
# 700           0.2074711476656672
# 800           0.2106375988173994
# 900           0.19791549801507718
# 1000          0.19820060879945645
# 1100          0.19544769832878314
# 1200          0.19125082935194482
# 1300          0.1867262727964045
# 1400          0.1849814193002142
# 1500          0.19786511974167012

# %%
grafico("../log/Versicolor-Chi/c1_sigma05_penalization10.log")
tabella("../log/Versicolor-Chi/c1_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.054898311425086575
# 200           0.15319624142579713
# 300           0.2902449580664694
# 400           0.2980208019274603
# 500           0.2981596611793496
# 600           0.5000035428298223
# 700           0.5000043966601153
# 800           0.5000036644657408
# 900           0.5000034663296269
# 1000          0.2888385946355363
# 1100          0.500003396680682
# 1200          0.5000041219996898
# 1300          0.5000037880551568
# 1400          0.2922850639161732
# 1500          0.5000037051457326

# %%
grafico("../log/Versicolor-Chi/c1_sigma05_penalization100.log")
tabella("../log/Versicolor-Chi/c1_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1597426741424757
# 200           0.14188064272126455
# 300           0.12015660969891181
# 400           0.2887692674331272
# 500           0.288714701822442
# 600           0.288666624196461
# 700           0.2887837801481671
# 800           0.28875008585011075
# 900           0.2887513561268128
# 1000          0.2887112023539981
# 1100          0.28867503455741855
# 1200          0.2886744966685737
# 1300          0.28864914648450796
# 1400          0.28861807453423605
# 1500          0.28862003880479475

# %%
grafico("../log/Versicolor-Chi/c1_sigma025_penalization01.log")
tabella("../log/Versicolor-Chi/c1_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1843452568274507
# 200           0.23114661845956574
# 300           0.2564868013108186
# 400           0.24615897721772798
# 500           0.23714211455370457
# 600           0.23005987154646512
# 700           0.22918137539376035
# 800           0.24116296463731993
# 900           0.24539506298958844
# 1000          0.22776393561996042
# 1100          0.2465203917953133
# 1200          0.24802897779186842
# 1300          0.25229891916062575
# 1400          0.23971070189597726
# 1500          0.2348195240497811

# %%
grafico("../log/Versicolor-Chi/c1_sigma025_penalization10.log")
tabella("../log/Versicolor-Chi/c1_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.11524032320363928
# 200           0.2605653683512534
# 300           0.31605530781960467
# 400           0.3281487328452996
# 500           0.3282175886741419
# 600           0.3248072240508527
# 700           0.3275961131925882
# 800           0.32719993324738816
# 900           0.31917652359683724
# 1000          0.32618952494569337
# 1100          0.3133859545869694
# 1200          0.32529686710984934
# 1300          0.32474781466742036
# 1400          0.32422068384312963
# 1500          0.323747140156511

# %%
grafico("../log/Versicolor-Chi/c1_sigma025_penalization100.log")
tabella("../log/Versicolor-Chi/c1_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.13554448915428377
# 200           0.23602622815287638
# 300           0.2927727802998388
# 400           0.5000025388284182
# 500           0.50000238821672
# 600           0.5000030347822442
# 700           0.500003016483265
# 800           0.5000023509696024
# 900           0.5000024029818032
# 1000          0.5000029541386796
# 1100          0.5000023937562673
# 1200          0.5000027163431764
# 1300          0.5000029221768896
# 1400          0.5000029064648438
# 1500          0.500002917348106

# %%
grafico("../log/Versicolor-Chi/c005_sigma01_penalization10.log")
tabella("../log/Versicolor-Chi/c005_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.372489546341792
# 200           0.29596452077360375
# 300           0.500001064206214
# 400           0.5000010677328094
# 500           0.5000010255856536
# 600           0.5000010258929598
# 700           0.5000010677247408
# 800           0.5000010895201268
# 900           0.5000011041005428
# 1000          0.5000010128089104
# 1100          0.5000010970938326
# 1200          0.500000934018265
# 1300          0.5000010058835332
# 1400          0.5000010912041364
# 1500          0.5000010441408745

# %%
grafico("../log/Versicolor-Chi/c005_sigma01_penalization100.log")
tabella("../log/Versicolor-Chi/c005_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.27557818201488893
# 200           0.2950454985792046
# 300           0.5000010808332047
# 400           0.33879286040031814
# 500           0.3388927553358523
# 600           0.33874502690503117
# 700           0.33863815426262966
# 800           0.500001100362479
# 900           0.5000010504138919
# 1000          0.9092077674408441
# 1100          0.909212083642009
# 1200          0.5000013254725254
# 1300          0.5000010153098753
# 1400          0.5000010165855256
# 1500          0.9092055846173477

# %%
grafico("../log/Versicolor-Chi/c005_sigma025_penalization01.log")
tabella("../log/Versicolor-Chi/c005_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.10807950835407731
# 200           0.2517679004377305
# 300           0.8459142029626404
# 400           0.8451902969524997
# 500           0.845392273104863
# 600           0.8455646601894193
# 700           0.8461281230471879
# 800           0.8455653087372605
# 900           0.8451052925648966
# 1000          0.8455421739010761
# 1100          0.8455635430615771
# 1200          0.8458131713902545
# 1300          0.8459965102087208
# 1400          0.8454672502678049
# 1500          0.8455109987181814

# %%
grafico("../log/Versicolor-Chi/c005_sigma025_penalization10.log")
tabella("../log/Versicolor-Chi/c005_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.14286271208827292
# 200           0.24517762662321654
# 300           0.31603147532553294
# 400           0.3124725054590403
# 500           0.31540852137672143
# 600           0.3140904107456646
# 700           0.3141179410998736
# 800           0.313425957544269
# 900           0.3126444719630657
# 1000          0.3119440039789202
# 1100          0.3112092891839102
# 1200          0.31064317352459336
# 1300          0.30971955739585294
# 1400          0.30708909584882743
# 1500          0.3084649501647036

# %%
grafico("../log/Versicolor-Chi/c005_sigma025_penalization100.log")
tabella("../log/Versicolor-Chi/c005_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.17426692657549972
# 200           0.2395549268797825
# 300           0.31167397626725163
# 400           0.31154746399248034
# 500           0.3114298990481871
# 600           0.31133461186461736
# 700           0.3112396639827048
# 800           0.3111450645024739
# 900           0.31105291905851823
# 1000          0.31095898447116715
# 1100          0.3108654061409865
# 1200          0.3107725897824069
# 1300          0.31068012851611637
# 1400          0.3105880160771141
# 1500          0.310481249735347

# %%
grafico("../log/Versicolor-Chi/c005_sigma05_penalization01.log")
tabella("../log/Versicolor-Chi/c005_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.17201765069932182
# 200           0.11067487059346692
# 300           0.28263682087201736
# 400           0.3100118592582718
# 500           0.3056856914626484
# 600           0.8611310543701965
# 700           0.31040868615506817
# 800           0.3116704369283755
# 900           0.3089294803027929
# 1000          0.8605966418844022
# 1100          0.30932654089139433
# 1200          0.8611298598584473
# 1300          0.3027755520230611
# 1400          0.3104120681249876
# 1500          0.8611384535846849

# %%
grafico("../log/Versicolor-Chi/c005_sigma05_penalization10.log")
tabella("../log/Versicolor-Chi/c005_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.04820060311371315
# 200           0.17389730986532256
# 300           0.29020204799351
# 400           0.2900259276898818
# 500           0.2898381021162326
# 600           0.28972025168157706
# 700           0.2895632420473316
# 800           0.2871554988641358
# 900           0.2892749537972389
# 1000          0.28908864874593215
# 1100          0.28898348363792875
# 1200          0.28886092900537536
# 1300          0.2886734841623129
# 1400          0.28855025879926266
# 1500          0.2884178351578614

# %%
grafico("../log/Versicolor-Chi/c005_sigma05_penalization100.log")
tabella("../log/Versicolor-Chi/c005_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           4.987875469403717e-08
# 200           0.18925919330190918
# 300           0.29365203625012337
# 400           0.29363114141605845
# 500           0.2936039289182665
# 600           0.29356292281946383
# 700           0.29350062520776776
# 800           0.29345911343900244
# 900           0.29339747334300403
# 1000          0.2933551357727006
# 1100          0.2932941899879739
# 1200          0.2932444467377429
# 1300          0.2932029739337435
# 1400          0.2931496843006725
# 1500          0.29309016117538605

# %%
grafico("../log/Versicolor-Chi/c75_sigma01_penalization01.log")
tabella("../log/Versicolor-Chi/c75_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.28444513867367377
# 200           0.5000024815136636
# 300           0.8657817743884181
# 400           0.5000033012141248
# 500           0.5000031411150108
# 600           0.29313624689930723
# 700           0.2864455268329576
# 800           0.28085688928501684
# 900           0.2678891117323208
# 1000          0.25176726749157347
# 1100          0.20824183752968203
# 1200          0.5000041687498796
# 1300          0.500004167240206
# 1400          0.8714961824797803
# 1500          0.5000041671917658

# %%
grafico("../log/Versicolor-Chi/c75_sigma01_penalization10.log")
tabella("../log/Versicolor-Chi/c75_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1946784749744163
# 200           0.3110442432003884
# 300           0.500001121506951
# 400           0.5000011187141171
# 500           0.5000010987060056
# 600           0.5000010663827499
# 700           0.5000011054464397
# 800           0.5000013195620049
# 900           0.500001005162848
# 1000          0.500001091552383
# 1100          0.5000010052828682
# 1200          0.5000010466614772
# 1300          0.500001059781234
# 1400          0.5000013073848824
# 1500          0.500000998408064

# %%
grafico("../log/Versicolor-Chi/c75_sigma01_penalization100.log")
tabella("../log/Versicolor-Chi/c75_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3999912486942286
# 200           0.30283704073178497
# 300           0.34456812646661755
# 400           0.5000010876828488
# 500           0.5000011326569619
# 600           0.5000010929562694
# 700           0.5000011134681303
# 800           0.5000011241954245
# 900           0.5000011007168914
# 1000          0.5000011020412461
# 1100          0.5000010967479257
# 1200          0.5000010271377119
# 1300          0.50000095100677
# 1400          0.5000010360820595
# 1500          0.5000011194090318

# %%
grafico("../log/Versicolor-Chi/c75_sigma025_penalization01.log")
tabella("../log/Versicolor-Chi/c75_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.24923069388875838
# 200           0.24727308201776613
# 300           0.26676132062632785
# 400           0.24455805638613531
# 500           0.250208066886137
# 600           0.24247590309196365
# 700           0.24377744790095265
# 800           0.2402832870025013
# 900           0.2512602854580462
# 1000          0.24752375520993158
# 1100          0.24537261148691678
# 1200          0.2488652954803504
# 1300          0.24281149103125516
# 1400          0.24812167929717574
# 1500          0.2513747347008148

# %%
grafico("../log/Versicolor-Chi/c75_sigma025_penalization10.log")
tabella("../log/Versicolor-Chi/c75_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.10339369961517508
# 200           0.24022889185640758
# 300           0.2880247280511478
# 400           0.3141086402610579
# 500           0.30808312362892926
# 600           0.3141499169915008
# 700           0.3139290475251434
# 800           0.313422362931085
# 900           0.30932726282769657
# 1000          0.3127992598629118
# 1100          0.31221391135123666
# 1200          0.3057023292064936
# 1300          0.3116379719351888
# 1400          0.3112075897311957
# 1500          0.31061911806235315

# %%
grafico("../log/Versicolor-Chi/c75_sigma025_penalization100.log")
tabella("../log/Versicolor-Chi/c75_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.07586090881846833
# 200           0.22821814902012236
# 300           0.16902401919902782
# 400           0.31241856968200143
# 500           0.3123460092693747
# 600           0.3122124930826715
# 700           0.31228994471416793
# 800           0.3122226702424767
# 900           0.3120874280541538
# 1000          0.31232791716075725
# 1100          0.312052307741606
# 1200          0.3120120699687886
# 1300          0.31191422778786404
# 1400          0.31181862431178287
# 1500          0.3118331659619291

# %%
grafico("../log/Versicolor-Chi/c75_sigma05_penalization01.log")
tabella("../log/Versicolor-Chi/c75_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           7.689217736709389e-08
# 200           0.08304192373557233
# 300           0.1646349351290869
# 400           0.22763053886477894
# 500           0.19938742884648672
# 600           0.21206281887677314
# 700           0.1962973000484846
# 800           0.194971321193391
# 900           0.19972830883788556
# 1000          0.18622178577509188
# 1100          0.17776454933073943
# 1200          0.18094677205888243
# 1300          0.1920319428580983
# 1400          0.1793259396741245
# 1500          0.1983018517070353

# %%
grafico("../log/Versicolor-Chi/c75_sigma05_penalization10.log")
tabella("../log/Versicolor-Chi/c75_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.19855053666803216
# 200           0.13944651392257548
# 300           0.2386684982457687
# 400           0.2917775274392438
# 500           0.2951704928527122
# 600           0.2978011494237402
# 700           0.28325248993596497
# 800           0.29465713554488543
# 900           0.2944368128398291
# 1000          0.29419504653079936
# 1100          0.2939616437507131
# 1200          0.29369884616962266
# 1300          0.2883331717879197
# 1400          0.29320415356630286
# 1500          0.2860940920834886

# %%
grafico("../log/Versicolor-Chi/c75_sigma05_penalization100.log")
tabella("../log/Versicolor-Chi/c75_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           7.240568996789034e-09
# 200           0.12913895316088062
# 300           0.10991802526925372
# 400           0.5000045894065808
# 500           0.5000033587006484
# 600           0.5000048989051072
# 700           0.5000044161525922
# 800           0.5000049466920452
# 900           0.29557157296208236
# 1000          0.5000048217470558
# 1100          0.5000046682962157
# 1200          0.5000044998155078
# 1300          0.5000046084341241
# 1400          0.5000046621194627
# 1500          0.5000046369728185

# %%
grafico("../log/Versicolor-Chi/c200_sigma01_penalization01.log")
tabella("../log/Versicolor-Chi/c200_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2865335166015562
# 200           0.5000026703630684
# 300           0.865878245019176
# 400           0.5000042142565511
# 500           0.5000038151112878
# 600           0.2926797458058872
# 700           0.28323231712731
# 800           0.2702218907389499
# 900           0.229381782142193
# 1000          0.207414178472967
# 1100          0.18209511262575542
# 1200          0.8246210956328799
# 1300          0.8246210956328799
# 1400          0.5000046934498923
# 1500          0.5000041687809845

# %%
grafico("../log/Versicolor-Chi/c200_sigma01_penalization10.log")
tabella("../log/Versicolor-Chi/c200_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.24051336760426442
# 200           0.32374799840612584
# 300           0.500001212105037
# 400           0.5000011696381588
# 500           0.5000011674590928
# 600           0.5000011598110756
# 700           0.5000011249716289
# 800           0.5000010714883207
# 900           0.5000009891652125
# 1000          0.5000011587261851
# 1100          0.5000009870516575
# 1200          0.500001151849969
# 1300          0.5000010982080468
# 1400          0.5000010987496607
# 1500          0.5000011450041111

# %%
grafico("../log/Versicolor-Chi/c200_sigma01_penalization100.log")
tabella("../log/Versicolor-Chi/c200_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.34106978042951763
# 200           0.28474281095910814
# 300           0.5000010199869067
# 400           0.5000010293664007
# 500           0.5000009525384035
# 600           0.5000009560367793
# 700           0.5000009497028041
# 800           0.5000009807076738
# 900           0.5000009963687936
# 1000          0.5000009364627102
# 1100          0.5000009835037011
# 1200          0.5000009908080508
# 1300          0.5000009630569363
# 1400          0.500000927835901
# 1500          0.5000009233021165

# %%
grafico("../log/Versicolor-Chi/c200_sigma025_penalization01.log")
tabella("../log/Versicolor-Chi/c200_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1931190103061077
# 200           0.2553207110513778
# 300           0.2589585963875726
# 400           0.24470397861129456
# 500           0.24047556042020976
# 600           0.22901431220451018
# 700           0.24275280861927884
# 800           0.24945851280096967
# 900           0.22720304151399073
# 1000          0.2406675642035846
# 1100          0.24197530280647986
# 1200          0.23643952622484546
# 1300          0.24525594185383967
# 1400          0.2512024144583378
# 1500          0.2508998108742433

# %%
grafico("../log/Versicolor-Chi/c200_sigma025_penalization10.log")
tabella("../log/Versicolor-Chi/c200_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1418098260155583
# 200           0.2522991388407373
# 300           0.5000030606087911
# 400           0.5000025418342855
# 500           0.5000024137349537
# 600           0.5000023670627896
# 700           0.5000029348521909
# 800           0.5000026257847525
# 900           0.5000028255666232
# 1000          0.3177138814719714
# 1100          0.5000028582806231
# 1200          0.31648393976655576
# 1300          0.5000021979224383
# 1400          0.31575048334434375
# 1500          0.5000024492732742

# %%
grafico("../log/Versicolor-Chi/c200_sigma025_penalization100.log")
tabella("../log/Versicolor-Chi/c200_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.14222731886209858
# 200           0.24447808784762892
# 300           0.2627534523923587
# 400           0.31761346400460105
# 500           0.31735849616065803
# 600           0.31726559662275466
# 700           0.3174388350569034
# 800           0.3171863369571922
# 900           0.31722994396264836
# 1000          0.31747975301764747
# 1100          0.31721340388867164
# 1200          0.31714944229204467
# 1300          0.3171605803554334
# 1400          0.3171573709786633
# 1500          0.31706226189529896

# %%
grafico("../log/Versicolor-Chi/c200_sigma05_penalization01.log")
tabella("../log/Versicolor-Chi/c200_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.05723516143164204
# 200           0.10481663449743232
# 300           0.1557554887420809
# 400           0.15577016298327784
# 500           0.19784647859262053
# 600           0.20714883751396496
# 700           0.21587332544487284
# 800           0.1954990525622191
# 900           0.19332079408544478
# 1000          0.1919287519321954
# 1100          0.19995802852363573
# 1200          0.18648490614589264
# 1300          0.19600437011728042
# 1400          0.20100544793504302
# 1500          0.1917506333968969

# %%
grafico("../log/Versicolor-Chi/c200_sigma05_penalization10.log")
tabella("../log/Versicolor-Chi/c200_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           4.739101266220207e-08
# 200           0.1739261263577922
# 300           0.24857610826516174
# 400           0.28672280303143266
# 500           0.28667723015898905
# 600           0.2887759557587401
# 700           0.28904953328739436
# 800           0.28883736408314004
# 900           0.2877440130449036
# 1000          0.2884484583825224
# 1100          0.2882870716468605
# 1200          0.28808085763054675
# 1300          0.28795213478306714
# 1400          0.2877994025544834
# 1500          0.2876897723246912

# %%
grafico("../log/Versicolor-Chi/c200_sigma05_penalization100.log")
tabella("../log/Versicolor-Chi/c200_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           4.535449001752294e-09
# 200           0.16645972463686473
# 300           0.26287601662387533
# 400           0.29060260402693283
# 500           0.2905369630742576
# 600           0.2905225300620238
# 700           0.28740592407784044
# 800           0.2904352536765006
# 900           0.2904235559876123
# 1000          0.29045535865178107
# 1100          0.2904026546756654
# 1200          0.29036933568590934
# 1300          0.29033364915870774
# 1400          0.2902809673227323
# 1500          0.2903128462015236
