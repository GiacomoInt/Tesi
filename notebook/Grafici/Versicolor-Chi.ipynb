# %% [markdown]
# ### Codice

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def grafico(path):

    coppie = lettura_log(path)

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %%
def tabella(path):

    coppie = lettura_log(path)
    
    print ("N_ITER        RMSE_DISTANCE")
    for i in coppie:
        print ("{:<14}{:<11}".format(*i))

# %% [markdown]
# # Versicolor

# %%
grafico("../../log/Versicolor-Chi/c1_sigma01_penalization01.log")
tabella("../../log/Versicolor-Chi/c1_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.30912331420861733
# 200           0.5000022085537196
# 300           0.8659318294057685
# 400           0.8658778271403089
# 500           0.8659147554194707
# 600           0.8660016591383094
# 700           0.5000045458359706
# 800           0.28921413048411665
# 900           0.2846331771969946
# 1000          0.25634192974654985
# 1100          0.18889807348219753
# 1200          0.12546353467736782
# 1300          0.12476124036205079
# 1400          0.1248594528878919
# 1500          0.12485921382572815

# %%
grafico("../../log/Versicolor-Chi/c1_sigma01_penalization10.log")
tabella("../../log/Versicolor-Chi/c1_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.423528611243193
# 200           0.5000011677754296
# 300           0.5000007848412834
# 400           0.5000009950298769
# 500           0.5000009638988634
# 600           0.5000007892788192
# 700           0.5000010587247018
# 800           0.5000010543255651
# 900           0.5000010475639146
# 1000          0.5000011078303981
# 1100          0.5000007542649407
# 1200          0.5000010426936793
# 1300          0.5000010514110679
# 1400          0.5000011140098635
# 1500          0.5000010456595526

# %%
grafico("../../log/Versicolor-Chi/c1_sigma01_penalization100.log")
tabella("../../log/Versicolor-Chi/c1_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.42653351348810964
# 200           0.310180488354802
# 300           0.34583761475992547
# 400           0.5000009839853643
# 500           0.5000011394724954
# 600           0.5000010786704681
# 700           0.5000007915059778
# 800           0.5000010644567803
# 900           0.5000011293067353
# 1000          0.500000788277487
# 1100          0.500000787121855
# 1200          0.5000009497814741
# 1300          0.5000009432705694
# 1400          0.5000010597002245
# 1500          0.5000011132220559

# %%
grafico("../../log/Versicolor-Chi/c1_sigma05_penalization01.log")
tabella("../../log/Versicolor-Chi/c1_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.12956975206436983
# 200           0.16255522969886563
# 300           0.13502648223449173
# 400           0.121557781870818
# 500           0.1243848828360988
# 600           0.1101347620549818
# 700           0.12046018558396329
# 800           0.12074226585629921
# 900           0.1224166169057267
# 1000          0.12274430559767743
# 1100          0.131334676711635
# 1200          0.13014108637974586
# 1300          0.12449212911456384
# 1400          0.1353234333049864
# 1500          0.13651847807513004

# %%
grafico("../../log/Versicolor-Chi/c1_sigma05_penalization10.log")
tabella("../../log/Versicolor-Chi/c1_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.11468804206486746
# 200           0.1284483857463291
# 300           0.042399154434655584
# 400           0.024291967519237567
# 500           0.025010728451920095
# 600           0.025652290008030543
# 700           0.02616845077995933
# 800           0.0266867065964268
# 900           0.027284902768252906
# 1000          0.027813930455313607
# 1100          0.028285657009383625
# 1200          0.0299952072644063
# 1300          0.02921970716575739
# 1400          0.029742970625461274
# 1500          0.030203133891559764

# %%
grafico("../../../log/Versicolor-Chi/c1_sigma05_penalization100.log")
tabella("../../log/Versicolor-Chi/c1_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.06421324902727327
# 200           0.14113705164888254
# 300           0.023710469853815974
# 400           0.024685667160138536
# 500           0.024634773908196683
# 600           0.024657999539873132
# 700           0.0244020529302188
# 800           0.026923028859688503
# 900           0.024594019391063815
# 1000          0.024432456859958096
# 1100          0.02451329692583676
# 1200          0.02453635771479956
# 1300          0.024580012405752028
# 1400          0.02464183091278721
# 1500          0.024675133207194333

# %%
grafico("../../log/Versicolor-Chi/c1_sigma025_penalization01.log")
tabella("../../log/Versicolor-Chi/c1_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.02252958167466318
# 200           0.0741232928457187
# 300           0.08984247210825061
# 400           0.07409223818747121
# 500           0.07150354533799094
# 600           0.06800608682880657
# 700           0.06109600125827089
# 800           0.060391873473240626
# 900           0.06057718585982716
# 1000          0.06521810401658582
# 1100          0.05070379266229921
# 1200          0.06667034814308906
# 1300          0.06439064722609242
# 1400          0.06087582245542958
# 1500          0.06086306029599434

# %%
grafico("../../log/Versicolor-Chi/c1_sigma025_penalization10.log")
tabella("../../log/Versicolor-Chi/c1_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.083168964268268
# 200           0.05137250572345484
# 300           0.12288297962934205
# 400           0.3000020592684335
# 500           0.30000203118488034
# 600           0.30000148357364087
# 700           0.30000206353635617
# 800           0.3000019048589362
# 900           0.3000020917872258
# 1000          0.300002026204225
# 1100          0.30000142117970074
# 1200          0.30000168916368963
# 1300          0.300002044023123
# 1400          0.3000018637234867
# 1500          0.3000019680496445

# %%
grafico("../../log/Versicolor-Chi/c1_sigma025_penalization100.log")
tabella("../../log/Versicolor-Chi/c1_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.12699265631085818
# 200           0.048634914208566526
# 300           0.10583309121364368
# 400           0.12611482457257003
# 500           0.12562529955873766
# 600           0.12580240162617387
# 700           0.12597198455083222
# 800           0.12588535068415344
# 900           0.12587929422227315
# 1000          0.12585090651426115
# 1100          0.12608529783682296
# 1200          0.12620382942214495
# 1300          0.12530801943598316
# 1400          0.12554808711765278
# 1500          0.1256337371016529

# %%
grafico("../../log/Versicolor-Chi/c005_sigma01_penalization10.log")
tabella("../../log/Versicolor-Chi/c005_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.42898499875472557
# 200           2.51324935778334e-08
# 300           1.8777127642988607e-08
# 400           0.2680406533750289
# 500           0.5000011100158146
# 600           0.5000007849034152
# 700           0.5000007830480845
# 800           0.5000007820519256
# 900           0.5000007925151907
# 1000          0.5000007741991438
# 1100          0.5000007723993455
# 1200          0.5000007705616247
# 1300          0.5000007687150853
# 1400          0.5000009682410786
# 1500          0.5000007791543533

# %%
grafico("../../log/Versicolor-Chi/c005_sigma01_penalization100.log")
tabella("../../log/Versicolor-Chi/c005_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2041149703480105
# 200           0.26187151271267445
# 300           0.500000957014676
# 400           0.5000007797548736
# 500           0.5000011092894846
# 600           0.5000010365492236
# 700           0.50000110038222
# 800           0.5000007497416842
# 900           0.5000011012768919
# 1000          0.5000007546362261
# 1100          0.5000010368850559
# 1200          0.500001040024912
# 1300          0.5000010990159526
# 1400          0.5000007531077919
# 1500          0.5000007500013166

# %%
grafico("../../log/Versicolor-Chi/c005_sigma025_penalization01.log")
tabella("../../log/Versicolor-Chi/c005_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.04117456183165483
# 200           0.05943274474170829
# 300           0.6205869890012787
# 400           0.6205887660265803
# 500           0.6205937911222044
# 600           0.620596738876114
# 700           0.620597956589193
# 800           0.6205991634311214
# 900           0.6205995275669376
# 1000          0.620600641947527
# 1100          0.6205995137749372
# 1200          0.6206006193925948
# 1300          0.6206007335796624
# 1400          0.6206009648249939
# 1500          0.6206009712827456

# %%
grafico("../../log/Versicolor-Chi/c005_sigma025_penalization10.log")
tabella("../../log/Versicolor-Chi/c005_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.017425814143604473
# 200           0.056066164926190265
# 300           0.30000196773214544
# 400           0.30000190657721443
# 500           0.30000167902306824
# 600           0.3000018500476446
# 700           0.30000138886828803
# 800           0.30000194768990435
# 900           0.30000182655806845
# 1000          0.30000163567812194
# 1100          0.3000018213812103
# 1200          0.30000202588193675
# 1300          0.30000179702240976
# 1400          0.3000020263531767
# 1500          0.30000200482669087

# %%
grafico("../../log/Versicolor-Chi/c005_sigma025_penalization100.log")
tabella("../../log/Versicolor-Chi/c005_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.07755456473707212
# 200           0.06151351356551271
# 300           0.3000020763044991
# 400           0.3000015415459755
# 500           0.3000021630687901
# 600           0.3000020150742348
# 700           0.3000020091790358
# 800           0.3000021225743033
# 900           0.30000149599930187
# 1000          0.30000211327711773
# 1100          0.3000018082016119
# 1200          0.30000200323903653
# 1300          0.300001798871892
# 1400          0.30000198876171374
# 1500          0.3000019821557333

# %%
grafico("../../log/Versicolor-Chi/c005_sigma05_penalization01.log")
tabella("../../log/Versicolor-Chi/c005_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.03091655273694799
# 200           0.10292730470972336
# 300           0.04106122404491119
# 400           0.0044177708415008565
# 500           0.0056398104024023565
# 600           0.004977190347282667
# 700           0.003039580033836531
# 800           0.013163448896821306
# 900           0.011810163809428897
# 1000          0.008055934127318476
# 1100          0.005958152822471974
# 1200          0.011398143408657524
# 1300          0.009187881391988562
# 1400          0.0187483766487182
# 1500          0.005138671821029506

# %%
grafico("../../log/Versicolor-Chi/c005_sigma05_penalization10.log")
tabella("../../log/Versicolor-Chi/c005_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.11478177225531452
# 200           0.05332578477797778
# 300           0.005015617199484013
# 400           0.004119265657023974
# 500           0.0032768498241234623
# 600           0.0022263607255836315
# 700           0.0022824352569721373
# 800           0.001727050768230487
# 900           0.0003770798813188536
# 1000          0.0010148429492477518
# 1100          0.000712535908907741
# 1200          0.00016509885907478594
# 1300          9.994210529429282e-05
# 1400          0.0003778901104089516
# 1500          0.0006502256740370527

# %%
grafico("../../log/Versicolor-Chi/c005_sigma05_penalization100.log")
tabella("../../log/Versicolor-Chi/c005_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1107337487785558
# 200           0.07282087576398272
# 300           0.19617468779913372
# 400           0.19617554410944105
# 500           0.19617472375072553
# 600           0.19617460274315135
# 700           0.1961747789031174
# 800           0.19617460463931458
# 900           0.19617483823595794
# 1000          0.19617483967212956
# 1100          0.19617470047237107
# 1200          0.19617483228965582
# 1300          0.19617544840461343
# 1400          0.19617482218122706
# 1500          0.19617544595250525

# %%
grafico("../../log/Versicolor-Chi/c75_sigma01_penalization01.log")
tabella("../../log/Versicolor-Chi/c75_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.32165522149666365
# 200           0.5000020295374731
# 300           0.8659442682765536
# 400           0.8659702835665746
# 500           0.8659737276836799
# 600           0.500003787246431
# 700           0.2944045284386183
# 800           0.2898116004219033
# 900           0.286976001616258
# 1000          0.26911506301766863
# 1100          0.21717380956348437
# 1200          0.12459910073780539
# 1300          0.12484973525975776
# 1400          0.12483118256277112
# 1500          0.12485732476776261

# %%
grafico("../../log/Versicolor-Chi/c75_sigma01_penalization10.log")
tabella("../../log/Versicolor-Chi/c75_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3743940986699847
# 200           0.32348812280675404
# 300           0.5000009641205908
# 400           0.5000010589721707
# 500           0.500001040116054
# 600           0.5000011213538352
# 700           0.5000010821577213
# 800           0.5000010077214216
# 900           0.5000007426595724
# 1000          0.5000009943353342
# 1100          0.5000009958780677
# 1200          0.5000008887102817
# 1300          0.5000010498204049
# 1400          0.5000007329514384
# 1500          0.5000008862285226

# %%
grafico("../../log/Versicolor-Chi/c75_sigma01_penalization100.log")
tabella("../../log/Versicolor-Chi/c75_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.41300681813791074
# 200           0.2811043560403461
# 300           0.5000011858855421
# 400           0.5000007630854854
# 500           0.5000010241824984
# 600           0.500001068883663
# 700           0.5000008979625871
# 800           0.5000007304992494
# 900           0.5000009836626019
# 1000          0.5000010893713767
# 1100          0.500000889643161
# 1200          0.5000008887372562
# 1300          0.5000010739849651
# 1400          0.500000879799622
# 1500          0.5000010427965945

# %%
grafico("../../log/Versicolor-Chi/c75_sigma025_penalization01.log")
tabella("../../log/Versicolor-Chi/c75_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.0692305432197281
# 200           0.03483920317788766
# 300           0.09264149813864792
# 400           0.0848851234045549
# 500           0.0703880792164443
# 600           0.06488522030847621
# 700           0.06439939061092043
# 800           0.054843978446728114
# 900           0.06308604919856725
# 1000          0.06611402436069702
# 1100          0.0601727639396063
# 1200          0.05810525804659261
# 1300          0.04858143077807872
# 1400          0.06606259024459066
# 1500          0.0547242798923564

# %%
grafico("../../log/Versicolor-Chi/c75_sigma025_penalization10.log")
tabella("../../log/Versicolor-Chi/c75_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.025778517629563763
# 200           0.04695433232974838
# 300           0.05496460302384726
# 400           0.3000021249502193
# 500           0.30000158204876404
# 600           0.3000018501141697
# 700           0.30000201824357975
# 800           0.3000021266467403
# 900           0.30000210844586983
# 1000          0.3000014901288013
# 1100          0.30000197906299986
# 1200          0.3000019650998651
# 1300          0.30000143597787776
# 1400          0.3000019600710244
# 1500          0.3000014593053939

# %%
grafico("../../log/Versicolor-Chi/c75_sigma025_penalization100.log")
tabella("../../log/Versicolor-Chi/c75_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.11714232108565492
# 200           0.02348244973777644
# 300           7.43966832583709e-11
# 400           0.126532218591542
# 500           0.12589778445579197
# 600           0.12635233843252214
# 700           0.12635154637973944
# 800           0.12645574296667011
# 900           0.12668972086901636
# 1000          0.12617022839579328
# 1100          0.12657022776434518
# 1200          0.12689468397843223
# 1300          0.12592494851330543
# 1400          0.12606481919687634
# 1500          0.12589276155202667

# %%
grafico("../../log/Versicolor-Chi/c75_sigma05_penalization01.log")
tabella("../../log/Versicolor-Chi/c75_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.08583151541649409
# 200           0.15598474143403743
# 300           0.15978319376429842
# 400           0.13018026983058284
# 500           0.1284488865484012
# 600           0.1348842547238515
# 700           0.1078637828874511
# 800           0.11407025953577471
# 900           0.11324000941484283
# 1000          0.11612201258061955
# 1100          0.12086355909312543
# 1200          0.12621398343811532
# 1300          0.11793075610297665
# 1400          0.11322162663606952
# 1500          0.13143794386446653

# %%
grafico("../../log/Versicolor-Chi/c75_sigma05_penalization10.log")
tabella("../../log/Versicolor-Chi/c75_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.042188184125254435
# 200           0.0683808124197417
# 300           0.020409794523307545
# 400           0.16456768266381971
# 500           0.16456672358555924
# 600           0.16456689072147646
# 700           0.16456681429609954
# 800           0.16456679955408582
# 900           0.023422980964449558
# 1000          0.16456728203259452
# 1100          0.16456672102800196
# 1200          0.16456722435098592
# 1300          0.16456666934375386
# 1400          0.16456661682069795
# 1500          0.16456661052046728

# %%
grafico("../../log/Versicolor-Chi/c75_sigma05_penalization100.log")
tabella("../../log/Versicolor-Chi/c75_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1451062479573311
# 200           0.11509250400927806
# 300           0.044854958600308026
# 400           0.015569062615553464
# 500           0.015925583356003747
# 600           0.015722121041033155
# 700           0.01859199103387632
# 800           0.015814918015253088
# 900           0.01591739812963644
# 1000          0.015942545844781886
# 1100          0.015986223014749
# 1200          0.015954998724078573
# 1300          0.016029241830182395
# 1400          0.016092724819632087
# 1500          0.01611796907428631

# %%
grafico("../../log/Versicolor-Chi/c200_sigma01_penalization01.log")
tabella("../../log/Versicolor-Chi/c200_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2824307377424077
# 200           0.2883706381761018
# 300           0.3125038406773747
# 400           0.9128708905915984
# 500           0.5000035751382352
# 600           0.39999996141632155
# 700           0.2928259267086713
# 800           0.28840544918238764
# 900           0.2830898720521717
# 1000          0.2623396018628027
# 1100          0.2231876096330884
# 1200          0.12693552296025096
# 1300          0.12489252402983783
# 1400          0.12486558646373415
# 1500          0.1247922035770781

# %%
grafico("../../log/Versicolor-Chi/c200_sigma01_penalization10.log")
tabella("../../log/Versicolor-Chi/c200_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.35781398045557916
# 200           0.29362416722391993
# 300           0.31651542313846753
# 400           0.5000009467442649
# 500           0.5000007608775336
# 600           0.500000915038364
# 700           0.50000074611989
# 800           0.5000011156414952
# 900           0.5000007439383731
# 1000          0.5000010718134323
# 1100          0.5000007382468755
# 1200          0.5000010567540456
# 1300          0.5000010539667723
# 1400          0.5000009993758057
# 1500          0.5000007380607858

# %%
grafico("../../log/Versicolor-Chi/c200_sigma01_penalization100.log")
tabella("../../log/Versicolor-Chi/c200_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3641452873893218
# 200           0.31312888287842694
# 300           0.5000008076684159
# 400           0.5000007958515724
# 500           0.5000008172403178
# 600           0.5000010998525974
# 700           0.500001159536726
# 800           0.5000008089068774
# 900           0.5000007849058666
# 1000          0.500001146341319
# 1100          0.5000007815066668
# 1200          0.5000007906083015
# 1300          0.5000011535304585
# 1400          0.50000078655817
# 1500          0.5000011428811469

# %%
grafico("../../log/Versicolor-Chi/c200_sigma025_penalization01.log")
tabella("../../log/Versicolor-Chi/c200_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.012504646760313154
# 200           0.0622837506113231
# 300           0.09406068099597478
# 400           0.08634825304466068
# 500           0.06816011313959572
# 600           0.06888308909222293
# 700           0.06137440277786968
# 800           0.05954682237916595
# 900           0.05852731287972676
# 1000          0.05827043694389619
# 1100          0.05832668759142248
# 1200          0.05418593685021225
# 1300          0.04861188395761115
# 1400          0.05063238702689152
# 1500          0.05850442281167115

# %%
grafico("../../log/Versicolor-Chi/c200_sigma025_penalization10.log")
tabella("../../log/Versicolor-Chi/c200_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.07663810526665929
# 200           0.04510305187541078
# 300           0.10167708769476339
# 400           0.1284188179392496
# 500           0.30000186735868184
# 600           0.12795004662241957
# 700           0.12790378667633664
# 800           0.12788901524169735
# 900           0.12756858417610525
# 1000          0.12707120824869797
# 1100          0.12655503420776062
# 1200          0.12608044507192404
# 1300          0.1258148907471859
# 1400          0.1251449323197342
# 1500          0.12488923524787363

# %%
grafico("../../log/Versicolor-Chi/c200_sigma025_penalization100.log")
tabella("../../log/Versicolor-Chi/c200_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1593345306028884
# 200           0.07265014921377957
# 300           0.13411900908681249
# 400           0.30000181001515136
# 500           0.3000017839304626
# 600           0.30000171506466344
# 700           0.30000164887715697
# 800           0.30000156079759555
# 900           0.30000167664909505
# 1000          0.3000017265860374
# 1100          0.30000167797980903
# 1200          0.3000016275640608
# 1300          0.30000153382938677
# 1400          0.3000015333258812
# 1500          0.3000015410436683

# %%
grafico("../../log/Versicolor-Chi/c200_sigma05_penalization01.log")
tabella("../../log/Versicolor-Chi/c200_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.07502586839387604
# 200           0.10944488609185285
# 300           0.1550202338048425
# 400           0.13226175087174516
# 500           0.13124482198910453
# 600           0.1167582153777813
# 700           0.10306003136252656
# 800           0.12046781454299268
# 900           0.1285060143980551
# 1000          0.11637865231937178
# 1100          0.12043337144583194
# 1200          0.13138969832670327
# 1300          0.11808614499102638
# 1400          0.12377415135441364
# 1500          0.1320132383580407

# %%
grafico("../../log/Versicolor-Chi/c200_sigma05_penalization10.log")
tabella("../../log/Versicolor-Chi/c200_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.09370220704684787
# 200           0.10926523276146877
# 300           0.031404313660814476
# 400           0.020392979724461857
# 500           0.02044111683476385
# 600           0.01900909624514263
# 700           0.019783559966038866
# 800           0.020101246558102803
# 900           0.020703018129544948
# 1000          0.026654812116594706
# 1100          0.021839689348008673
# 1200          0.022304975660327797
# 1300          0.02280350752212973
# 1400          0.023128608809616424
# 1500          0.02356285879642933

# %%
grafico("../../log/Versicolor-Chi/c200_sigma05_penalization100.log")
tabella("../../log/Versicolor-Chi/c200_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.0034434851301617386
# 200           0.08434538437263683
# 300           0.04226451922968205
# 400           0.010225801348397123
# 500           0.010051049205764107
# 600           0.009866869530632982
# 700           0.00980987574471831
# 800           0.009805382666307372
# 900           0.009917468390430229
# 1000          0.009914947955209696
# 1100          0.009976085293255388
# 1200          0.010035414721902003
# 1300          0.00998763379192702
# 1400          0.009986378780121097
# 1500          0.010128003156265442
