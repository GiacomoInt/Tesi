# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[4].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def grafico(path):

    coppie = lettura_log(path)

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %% [markdown]
# # Prova 1
# **Classe** : Setosa
#
# **Parametri** : C=1, GaussianKernel(0.25), penalization = 10
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/base.log')

# %% [markdown]
# # Prova 2
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.25), penalization = 10
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/c005.log')

# %% [markdown]
# # Prova 3
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.25), penalization = 10
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/c75.log')

# %% [markdown]
# # Prova 4
# **Classe** : Setosa
#
# **Parametri** : C=200, GaussianKernel(0.25), penalization = 10
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/c200.log')

# %% [markdown]
# # Prova 5
# **Classe** : Setosa
#
# **Parametri** : C=1, GaussianKernel(0.1), penalization = 10
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/sigma01.log')

# %% [markdown]
# # Prova 6
# **Classe** : Setosa
#
# **Parametri** : C=1, GaussianKernel(0.5), penalization = 10
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/sigma05.log')

# %% [markdown]
# # Prova 7
# **Classe** : Setosa
#
# **Parametri** : C=1, GaussianKernel(0.25), penalization = 0.1
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/penalization01.log')

# %% [markdown]
# # Prova 8
# **Classe** : Setosa
#
# **Parametri** : C=1, GaussianKernel(0.5), penalization = 0.1
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/sigma05_penalization01.log')

# %% [markdown]
# # Prova 9
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.1), penalization = 0.1
#
# **N_iter** 100 -> 1500

# %%
#grafico('./log/Setosa/c005_sigma01_penalization01.log')

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %% [markdown]
# # Prova 10
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.1), penalization = 10
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c005_sigma01_penalization10.log')

# %% [markdown]
# # Prova 11
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.1), penalization = 100
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c005_sigma01_penalization100.log')

# %% [markdown]
# # Prova 12
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.5), penalization = 0.1
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c005_sigma05_penalization01.log')

# %% [markdown]
# # Prova 13
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.5), penalization = 10
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c005_sigma05_penalization10.log')

# %% [markdown]
# # Prova 14
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.5), penalization = 100
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c005_sigma05_penalization100.log')

# %% [markdown]
# # Prova 17
# **Classe** : Setosa
#
# **Parametri** : C=0.05, GaussianKernel(0.25), penalization = 100
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c005_sigma025_penalization100.log')

# %% [markdown]
# # Prova 18
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.1), penalization = 0.1
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma01_penalization01.log')

# %% [markdown]
# # Prova 19
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.1), penalization = 10
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma01_penalization10.log')

# %% [markdown]
# # Prova 20
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.1), penalization = 100
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma01_penalization100.log')

# %% [markdown]
# # Prova 21
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.5), penalization = 0.1
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma05_penalization01.log')

# %% [markdown]
# # Prova 22
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.5), penalization = 10
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma05_penalization10.log')

# %% [markdown]
# # Prova 23
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.5), penalization = 100
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma05_penalization100.log')

# %% [markdown]
# # Prova 24
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.25), penalization = 0.1
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma025_penalization01.log')

# %%
grafico('../log/prova2.log')

# %% [markdown]
# # Prova 25
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.25), penalization = 10
#
# **N_iter** 100 -> 150

# %%
grafico('../log/Setosa/c75_sigma025_penalization10.log')

# %% [markdown]
# # Prova 26
# **Classe** : Setosa
#
# **Parametri** : C=75, GaussianKernel(0.25), penalization = 100
#
# **N_iter** 100 -> 1500

# %%
grafico('../log/Setosa/c75_sigma025_penalization100.log')

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
grafico("../log/Setosa-Chi/c200_sigma05_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c200_sigma01_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c200_sigma025_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c75_sigma05_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c75_sigma01_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c75_sigma025_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c1_sigma05_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c1_sigma01_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c1_sigma025_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c005_sigma05_penalization01.log")

# %%
grafico("../log/Setosa-Chi/c005_sigma025_penalization01.log")
