# %% [markdown]
# ### Codice

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def grafico(path):

    coppie = lettura_log(path)

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %%
def tabella(path):

    coppie = lettura_log(path)
    
    print ("N_ITER        RMSE_DISTANCE")
    for i in coppie:
        print ("{:<14}{:<11}".format(*i))

# %% [markdown]
# # Setosa

# %%
grafico("../../log/Setosa-Chi/c1_sigma01_penalization01.log")
tabella("../../log/Setosa-Chi/c1_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2980732840909157
# 200           0.3090150868541802
# 300           0.5000034984320861
# 400           0.5000029927099531
# 500           0.5000045132131961
# 600           0.2920026657050218
# 700           0.2823339832204908
# 800           0.2702741344385574
# 900           0.25513472422656336
# 1000          0.21891637150272764
# 1100          0.8286268380067576
# 1200          0.8246210784333861
# 1300          0.8246210956329688
# 1400          0.8246210956329688
# 1500          0.5000046935318133

# %%
grafico("../../log/Setosa-Chi/c1_sigma01_penalization10.log")
tabella("../../log/Setosa-Chi/c1_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3935622446254786
# 200           0.2983459425095882
# 300           0.3516988780571656
# 400           0.5000011089044135
# 500           0.39999997050943664
# 600           0.3615129130806119
# 700           0.3999999705094357
# 800           0.39999997050943664
# 900           0.5000010849560597
# 1000          0.5000010313719782
# 1100          0.5000009931512458
# 1200          0.5000010285271945
# 1300          0.5000010268519967
# 1400          0.500000983942468
# 1500          0.5000010268915671

# %%
grafico("../../log/Setosa-Chi/c1_sigma01_penalization100.log")
tabella("../../log/Setosa-Chi/c1_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.35447248848766155
# 200           0.26886032157096273
# 300           0.2968462244887124
# 400           0.500000986348106
# 500           0.5000010265928491
# 600           0.5000010510337938
# 700           0.5000009911784588
# 800           0.5000010401938655
# 900           0.5000009916397845
# 1000          0.500001244397211
# 1100          0.5000010286480859
# 1200          0.5000009843234275
# 1300          0.5000009720854093
# 1400          0.5000009892949093
# 1500          0.5000010315340194

# %%
grafico("../../log/Setosa-Chi/c1_sigma05_penalization01.log")
tabella("../../log/Setosa-Chi/c1_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.06663222217657411
# 200           0.08162831575546062
# 300           0.18447018130069884
# 400           0.16895640638065265
# 500           0.17186601883659247
# 600           0.20264563297406735
# 700           0.18209183991703248
# 800           0.1875281581788454
# 900           0.1919627329125043
# 1000          0.20556492748043467
# 1100          0.19420370451079036
# 1200          0.2042528870348259
# 1300          0.17981447834834086
# 1400          0.17956298892701758
# 1500          0.18290627718083644

# %%
grafico("../../log/Setosa-Chi/c1_sigma05_penalization10.log")
tabella("../../log/Setosa-Chi/c1_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           2.9478527968448596e-08
# 200           0.14695348473931696
# 300           0.18210505281459144
# 400           0.29303264466063994
# 500           0.29315370623008147
# 600           0.2930972122741973
# 700           0.2931168979471849
# 800           0.2878400452921981
# 900           0.29122231945239113
# 1000          0.2927556952949846
# 1100          0.2925119914564745
# 1200          0.2923283822300395
# 1300          0.2898374104397291
# 1400          0.2935683133918527
# 1500          0.29169148514283155

# %%
grafico("../../log/Setosa-Chi/c1_sigma05_penalization100.log")
tabella("../../log/Setosa-Chi/c1_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           6.948830943534242e-08
# 200           0.14500674426208174
# 300           0.12842005794391484
# 400           0.29103852919202833
# 500           0.2910775252261939
# 600           0.2910614078994394
# 700           0.290982136412222
# 800           0.29097562249313275
# 900           0.29089764651674777
# 1000          0.2909099948242258
# 1100          0.2908897909128702
# 1200          0.2908743107761813
# 1300          0.2908574332058367
# 1400          0.29081829995373254
# 1500          0.2907866102418228

# %%
grafico("../../log/Setosa-Chi/c1_sigma025_penalization01.log")
tabella("../../log/Setosa-Chi/c1_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.21342729570305544
# 200           0.24450791669286245
# 300           0.26835526515344454
# 400           0.24819544376568187
# 500           0.24650491802434038
# 600           0.2307952518841151
# 700           0.2384831641174865
# 800           0.24406840173798472
# 900           0.248884821981564
# 1000          0.24215752935091778
# 1100          0.23835410544257277
# 1200          0.2491703822533939
# 1300          0.2551326247036491
# 1400          0.2461515811577835
# 1500          0.24460044384193563

# %%
grafico("../../log/Setosa-Chi/c1_sigma025_penalization10.log")
tabella("../../log/Setosa-Chi/c1_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.17745487070294033
# 200           0.2638192700245575
# 300           0.2997555109245322
# 400           0.3288093360796006
# 500           0.3274776998578364
# 600           0.32877647396564114
# 700           0.3283890494900141
# 800           0.3280315562094508
# 900           0.32747233385169766
# 1000          0.327004902689913
# 1100          0.3264584104610291
# 1200          0.3258738666899585
# 1300          0.3191433009906116
# 1400          0.3229750306088552
# 1500          0.32416764543029647

# %%
grafico("../../log/Setosa-Chi/c1_sigma025_penalization100.log")
tabella("../../log/Setosa-Chi/c1_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           6.118075056320257e-12
# 200           0.22820926038075354
# 300           0.20904558405194762
# 400           0.31724883019058436
# 500           0.3167752453345053
# 600           0.3999761600378546
# 700           0.31681571076233145
# 800           0.39999999999469943
# 900           0.31661560028674923
# 1000          0.3999999607450193
# 1100          0.4
# 1200          0.31643573477957104
# 1300          0.39999999999215624
# 1400          0.4
# 1500          0.3162500243254595

# %%
grafico("../../log/Setosa-Chi/c005_sigma01_penalization10.log")
tabella("../../log/Setosa-Chi/c005_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2492019293612633
# 200           0.18408119199041548
# 300           0.23075926630294608
# 400           0.18914968261328163
# 500           0.3999999705096187
# 600           0.3999999705096187
# 700           0.34470217858813573
# 800           0.40297297443319996
# 900           0.3438073162064295
# 1000          0.5000011148123485
# 1100          0.5000010209720015
# 1200          0.5000010117478935
# 1300          0.5000010071068334
# 1400          0.5000011774405146
# 1500          0.5000010784197991

# %%
grafico("../../log/Setosa-Chi/c005_sigma01_penalization100.log")
tabella("../../log/Setosa-Chi/c005_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.24475454072326633
# 200           0.25524299712105336
# 300           0.33374554577781507
# 400           0.3340642607052916
# 500           0.33433384276875555
# 600           0.3345112850171243
# 700           0.33454324792771917
# 800           0.3344940739467719
# 900           0.33453446944926823
# 1000          0.33459776293777305
# 1100          0.3345350035617195
# 1200          0.33426308604939786
# 1300          0.3343228737920863
# 1400          0.334272240960691
# 1500          0.3343142479290553

# %%
grafico("../../log/Setosa-Chi/c005_sigma025_penalization01.log")
tabella("../../log/Setosa-Chi/c005_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.137506603633807
# 200           0.23778218873136076
# 300           0.8430288682344135
# 400           0.8462038544144402
# 500           0.8458751352113081
# 600           0.8433234398480017
# 700           0.8437352361219587
# 800           0.8451972723593774
# 900           0.8455604855833774
# 1000          0.8441764912207498
# 1100          0.845814174594933
# 1200          0.8441172532396608
# 1300          0.8461541965962873
# 1400          0.8448409405447509
# 1500          0.8456840574948122

# %%
grafico("../../log/Setosa-Chi/c005_sigma025_penalization10.log")
tabella("../../log/Setosa-Chi/c005_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.14181119651263624
# 200           0.21434168915773724
# 300           0.3124545738510013
# 400           0.3116563939250809
# 500           0.31045858543492705
# 600           0.3101539490172099
# 700           0.3095839557397709
# 800           0.3089890695889353
# 900           0.30835576957235317
# 1000          0.3079059686968878
# 1100          0.3074050453906349
# 1200          0.30697524747394783
# 1300          0.2995270724131819
# 1400          0.3066820450694533
# 1500          0.30392105041448503

# %%
grafico("../../log/Setosa-Chi/c005_sigma025_penalization100.log")
tabella("../../log/Setosa-Chi/c005_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.13430983148436965
# 200           0.23626555410967987
# 300           0.30391526990503154
# 400           0.30398933651494225
# 500           0.3039565255429963
# 600           0.3039382087441306
# 700           0.3038872363182793
# 800           0.3038281015619026
# 900           0.3037902264251156
# 1000          0.30376784315667343
# 1100          0.30363753792288095
# 1200          0.3036167176076805
# 1300          0.303486382265559
# 1400          0.3033902521021177
# 1500          0.30330544059389464

# %%
grafico("../../log/Setosa-Chi/c005_sigma05_penalization01.log")
tabella("../../log/Setosa-Chi/c005_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           1.398963105608583e-08
# 200           0.13896594040613988
# 300           0.20743271155143275
# 400           0.3093745015698121
# 500           0.3076047057875493
# 600           0.2972926683253595
# 700           0.3133170536293727
# 800           0.2971838948194775
# 900           0.8604004728455773
# 1000          0.3097840777228712
# 1100          0.31296028093369493
# 1200          0.31005453648081693
# 1300          0.3038178913573186
# 1400          0.8607521866752906
# 1500          0.8608005372317039

# %%
grafico("../../log/Setosa-Chi/c005_sigma05_penalization10.log")
tabella("../../log/Setosa-Chi/c005_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.06564668396650387
# 200           0.18789892330544145
# 300           0.29242137802624746
# 400           0.29584918382370173
# 500           0.29547871832908
# 600           0.29507399133280854
# 700           0.2947332378352497
# 800           0.29440125366473213
# 900           0.2940927806666132
# 1000          0.293900740112003
# 1100          0.2933739815056187
# 1200          0.2931536918280654
# 1300          0.2927894175342606
# 1400          0.29250090492354786
# 1500          0.2921921919736293

# %%
grafico("../../log/Setosa-Chi/c005_sigma05_penalization100.log")
tabella("../../log/Setosa-Chi/c005_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.05049369991064726
# 200           0.1853981664104426
# 300           0.2911579750250959
# 400           0.2911100159308946
# 500           0.2910723806244268
# 600           0.2910281079473018
# 700           0.29097972483018375
# 800           0.2909433997049583
# 900           0.2908993861558472
# 1000          0.29085060650912314
# 1100          0.29081560987534405
# 1200          0.29077187330721255
# 1300          0.2907229616048262
# 1400          0.2906855889269917
# 1500          0.29063889391514175

# %%
grafico("../../log/Setosa-Chi/c75_sigma01_penalization01.log")
tabella("../../log/Setosa-Chi/c75_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.31907623949490216
# 200           0.5000027894124514
# 300           0.5000034396936521
# 400           0.5000032114548718
# 500           0.5000031955630891
# 600           0.2930345365101732
# 700           0.287001380498555
# 800           0.2868762468850144
# 900           0.27467872050038944
# 1000          0.24508972055439873
# 1100          0.8246210956331187
# 1200          0.8246210956331187
# 1300          0.8246210956331187
# 1400          0.8246210956331187
# 1500          0.8246210854706328

# %%
grafico("../../log/Setosa-Chi/c75_sigma01_penalization10.log")
tabella("../../log/Setosa-Chi/c75_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.22636065184253196
# 200           0.31607421605648905
# 300           0.5000011908510985
# 400           0.5000012754317654
# 500           0.5000011972268399
# 600           0.5000012025826179
# 700           0.50000118510083
# 800           0.5000011150054988
# 900           0.5000011009051483
# 1000          0.500001161335363
# 1100          0.5000011618740209
# 1200          0.5000011351099588
# 1300          0.5000010887546524
# 1400          0.5000011550322302
# 1500          0.500001165209987

# %%
grafico("../../log/Setosa-Chi/c75_sigma01_penalization100.log")
tabella("../../log/Setosa-Chi/c75_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.13840951134829704
# 200           0.2792537194711596
# 300           0.500001049351155
# 400           0.5000009809682461
# 500           0.5000011416831271
# 600           0.5000010485681301
# 700           0.500001092891931
# 800           0.5000010184610135
# 900           0.5000010098356513
# 1000          0.5000011136530702
# 1100          0.5000013378259534
# 1200          0.5000013337573109
# 1300          0.5000011041995183
# 1400          0.5000010550057196
# 1500          0.5000013240100116

# %%
grafico("../../log/Setosa-Chi/c75_sigma025_penalization01.log")
tabella("../../log/Setosa-Chi/c75_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.21344353214704137
# 200           0.2559419509427534
# 300           0.2652105260176575
# 400           0.25436036249178057
# 500           0.24548695223131828
# 600           0.23164156950931097
# 700           0.23778820055887387
# 800           0.23454901583196944
# 900           0.2450714318992757
# 1000          0.24903034019231224
# 1100          0.25025494490571404
# 1200          0.24951848504474874
# 1300          0.24926345404909855
# 1400          0.24269689158252122
# 1500          0.25185969653422285

# %%
grafico("../../log/Setosa-Chi/c75_sigma025_penalization10.log")
tabella("../../log/Setosa-Chi/c75_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.1360159760233968
# 200           0.2247698692688531
# 300           0.28813139962965817
# 400           0.30139329207389054
# 500           0.30375682190334785
# 600           0.30355319771317807
# 700           0.303345354463154
# 800           0.303172764753065
# 900           0.3030861366233445
# 1000          0.3027401881280139
# 1100          0.30253477376442106
# 1200          0.3023788039843349
# 1300          0.30207460409212816
# 1400          0.3018611457934136
# 1500          0.30160180982818685

# %%
grafico("../../log/Setosa-Chi/c75_sigma025_penalization100.log")
tabella("../../log/Setosa-Chi/c75_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.08385503341149422
# 200           0.24785498217349025
# 300           0.5000032283617418
# 400           0.5000025283166134
# 500           0.5000030909396019
# 600           0.500003061067599
# 700           0.5000028193107565
# 800           0.5000030139038253
# 900           0.5000024194385576
# 1000          0.5000031184010291
# 1100          0.5000030832442208
# 1200          0.5000029681893615
# 1300          0.500003082692521
# 1400          0.5000027543323721
# 1500          0.5000024066509012

# %%
grafico("../../log/Setosa-Chi/c75_sigma05_penalization01.log")
tabella("../../log/Setosa-Chi/c75_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.045006799896533556
# 200           0.09078607542491847
# 300           0.13673594556072147
# 400           0.22491168343653975
# 500           0.21513974884635811
# 600           0.21092778622417616
# 700           0.19024398984203858
# 800           0.19235354803433447
# 900           0.2039522121415452
# 1000          0.20322954070842933
# 1100          0.19714687576477052
# 1200          0.19544678710764174
# 1300          0.19272050829109905
# 1400          0.18956491691911004
# 1500          0.19787472725063732

# %%
grafico("../../log/Setosa-Chi/c75_sigma05_penalization10.log")
tabella("../../log/Setosa-Chi/c75_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           2.6574558542345822e-08
# 200           0.13444820916828046
# 300           0.17050370754416885
# 400           0.2849463402028727
# 500           0.29168364151740345
# 600           0.2919235975317662
# 700           0.2914013573584575
# 800           0.2830407224228797
# 900           0.29108262482515973
# 1000          0.29093800367752726
# 1100          0.2913530108587028
# 1200          0.29056174854275557
# 1300          0.28973721663876323
# 1400          0.2902324602671447
# 1500          0.2900227276212764

# %%
grafico("../../log/Setosa-Chi/c75_sigma05_penalization100.log")
tabella("../../log/Setosa-Chi/c75_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.04911916427452685
# 200           0.19779204994350524
# 300           0.2781509532414005
# 400           0.293755774751374
# 500           0.2937630062588158
# 600           0.29375164110072266
# 700           0.29372085209666504
# 800           0.29368267494549954
# 900           0.2936490221856638
# 1000          0.29360249369788227
# 1100          0.2935578382388044
# 1200          0.29351256099501544
# 1300          0.29345776172505517
# 1400          0.2934274914966649
# 1500          0.29339495145074346

# %%
grafico("../../log/Setosa-Chi/c200_sigma01_penalization01.log")
tabella("../../log/Setosa-Chi/c200_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.28868175136211066
# 200           0.3045950022044085
# 300           0.500003621414449
# 400           0.5000030071512059
# 500           0.5000030706012862
# 600           0.29075805274831856
# 700           0.2847402901228457
# 800           0.2763434847292216
# 900           0.2607014023353082
# 1000          0.23908883276657872
# 1100          0.21464412171665137
# 1200          0.28284278156626635
# 1300          0.8699178701918417
# 1400          0.5000041672251226
# 1500          0.5000044140646004

# %%
grafico("../../log/Setosa-Chi/c200_sigma01_penalization10.log")
tabella("../../log/Setosa-Chi/c200_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2097545257655261
# 200           0.29144532763150854
# 300           0.50000100323454
# 400           0.5000010313918527
# 500           0.5000010693385856
# 600           0.5000009625627055
# 700           0.5000009520362656
# 800           0.5000009819637781
# 900           0.5000012400608117
# 1000          0.5000012271712478
# 1100          0.500000935393695
# 1200          0.5000010175140982
# 1300          0.500001011593326
# 1400          0.5000012210747456
# 1500          0.5000012202327779

# %%
grafico("../../log/Setosa-Chi/c200_sigma01_penalization100.log")
tabella("../../log/Setosa-Chi/c200_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3703832922889345
# 200           0.3183652966115525
# 300           0.5000010563874018
# 400           0.5000010027908329
# 500           0.5000010548630079
# 600           0.5000010274909971
# 700           0.5000010229522677
# 800           0.5000010319771295
# 900           0.5000010233838673
# 1000          0.5000010453422045
# 1100          0.5000010122398528
# 1200          0.5000010142412882
# 1300          0.5000009729497984
# 1400          0.500000971986344
# 1500          0.5000010360246854

# %%
grafico("../../log/Setosa-Chi/c200_sigma025_penalization01.log")
tabella("../../log/Setosa-Chi/c200_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.21239546886272404
# 200           0.24915975049122344
# 300           0.2636967283300342
# 400           0.25096622153858705
# 500           0.2427034067091079
# 600           0.23536946478809448
# 700           0.23369408453946813
# 800           0.23774860366389633
# 900           0.2513302316735412
# 1000          0.2416433867221981
# 1100          0.23086840848413182
# 1200          0.2513451438469059
# 1300          0.24123794284378786
# 1400          0.2517816356217809
# 1500          0.24478244032786478

# %%
grafico("../../log/Setosa-Chi/c200_sigma025_penalization10.log")
tabella("../../log/Setosa-Chi/c200_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.047764790738486655
# 200           0.1801140185098989
# 300           0.26866184262380627
# 400           0.30452415222017654
# 500           0.30432475123693153
# 600           0.30419437784392034
# 700           0.3041961178329519
# 800           0.5000019883512811
# 900           0.5000022819829041
# 1000          0.5000021968444438
# 1100          0.5000020688849378
# 1200          0.5000021589901419
# 1300          0.5000019054899798
# 1400          0.5000020308040547
# 1500          0.5000020412269037

# %%
grafico("../../log/Setosa-Chi/c200_sigma025_penalization100.log")
tabella("../../log/Setosa-Chi/c200_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.10765603222560345
# 200           0.24214423704497484
# 300           0.2783683828005766
# 400           0.329886178214201
# 500           0.32946686769773326
# 600           0.3300198149914966
# 700           0.3299175173409093
# 800           0.32988604506935904
# 900           0.3297769236503414
# 1000          0.32971638306940293
# 1100          0.3297344954182253
# 1200          0.32967466960973374
# 1300          0.3295841502404034
# 1400          0.3295898987045891
# 1500          0.32942755352923214

# %%
grafico("../../log/Setosa-Chi/c200_sigma05_penalization01.log")
tabella("../../log/Setosa-Chi/c200_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.07164093167662976
# 200           0.11357133134825559
# 300           0.16117946840062228
# 400           0.19250922143859114
# 500           0.20943866203181957
# 600           0.19778310497048773
# 700           0.2094686857821708
# 800           0.19503991306255933
# 900           0.20396683107403202
# 1000          0.20694240440874098
# 1100          0.19410243452318823
# 1200          0.1843679925858521
# 1300          0.19301342530681556
# 1400          0.18962693840400885
# 1500          0.17981741845718396

# %%
grafico("../../log/Setosa-Chi/c200_sigma05_penalization10.log")
tabella("../../log/Setosa-Chi/c200_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           1.7824039587677306e-08
# 200           0.17966338810185967
# 300           0.226878970032672
# 400           0.2893711066718616
# 500           0.28767644153791055
# 600           0.2763348693103843
# 700           0.2840626352151591
# 800           0.2887204474431559
# 900           0.28869349949217593
# 1000          0.28099061996014746
# 1100          0.2855842591522855
# 1200          0.2883883776494032
# 1300          0.2884172253985852
# 1400          0.288373881650917
# 1500          0.28837939820013503

# %%
grafico("../../log/Setosa-Chi/c200_sigma05_penalization100.log")
tabella("../../log/Setosa-Chi/c200_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           9.69746487764042e-08
# 200           0.17052668997724393
# 300           0.21713697600119705
# 400           0.2978376365039933
# 500           0.29783081925033256
# 600           0.2977627203214884
# 700           0.29784044219226474
# 800           0.29786656273806217
# 900           0.29780459736693143
# 1000          0.29780307622844837
# 1100          0.297766292510046
# 1200          0.2977976753204644
# 1300          0.2978011128062954
# 1400          0.29769129974981384
# 1500          0.2976681156565668
