# %% [markdown]
# ### Codice

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def grafico(path):

    coppie = lettura_log(path)

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %%
def tabella(path):

    coppie = lettura_log(path)
    
    print ("N_ITER        RMSE_DISTANCE")
    for i in coppie:
        print ("{:<14}{:<11}".format(*i))

# %% [markdown]
# # Virginica

# %%
grafico("../../log/Virginica-Chi/c1_sigma01_penalization01.log")
tabella("../../log/Virginica-Chi/c1_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3248699779266564
# 200           0.5000019786984431
# 300           0.8655457660686139
# 400           0.8653773319637488
# 500           0.8654472514574721
# 600           0.8657822252915952
# 700           0.8659738333318394
# 800           0.866024526365482
# 900           0.2891948795492003
# 1000          0.28730325852707217
# 1100          0.2650319670882488
# 1200          0.15399811963399723
# 1300          0.15150021606958272
# 1400          0.15166268062802313
# 1500          0.15201796834349873

# %%
grafico("../../log/Virginica-Chi/c1_sigma01_penalization10.log")
tabella("../../log/Virginica-Chi/c1_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.41916000492935446
# 200           0.8722488566205469
# 300           0.8628675341416243
# 400           0.8611498860749306
# 500           0.86120525213698
# 600           0.8612339651783313
# 700           0.861258438533926
# 800           0.8612392570386793
# 900           0.8612296245148666
# 1000          0.8612333339297099
# 1100          0.8612235729260059
# 1200          0.8612275760752591
# 1300          0.8612368241590409
# 1400          0.8612432267381358
# 1500          0.8612440346681174

# %%
grafico("../../log/Virginica-Chi/c1_sigma01_penalization100.log")
tabella("../../log/Virginica-Chi/c1_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.405361578519915
# 200           0.29280970816195656
# 300           0.5000007307564982
# 400           0.5000010130255007
# 500           0.5000009545549122
# 600           0.5000010292334036
# 700           0.5000010519991743
# 800           0.5000010506046381
# 900           0.5000009191194117
# 1000          0.5000009150293894
# 1100          0.500001006678168
# 1200          0.5000010349824415
# 1300          0.5000009793441712
# 1400          0.5000010152505281
# 1500          0.5000009206335129

# %%
grafico("../../log/Virginica-Chi/c1_sigma05_penalization01.log")
tabella("../../log/Virginica-Chi/c1_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.09137218268846739
# 200           0.12229568682917308
# 300           0.1336817251618565
# 400           0.055047995244122905
# 500           0.05037183362157566
# 600           0.019525446589469475
# 700           0.036121323881245726
# 800           0.04805047734789164
# 900           0.035383899473111435
# 1000          0.03436876893661833
# 1100          0.03164799279908054
# 1200          0.033730348431224355
# 1300          0.027361075797409373
# 1400          0.023171174701619557
# 1500          0.02659070247906059

# %%
grafico("../../log/Virginica-Chi/c1_sigma05_penalization10.log")
tabella("../../log/Virginica-Chi/c1_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.009710950249323724
# 200           0.016439921156006454
# 300           0.04128606380676725
# 400           0.21547575441034456
# 500           0.6123207283541547
# 600           0.21547543095884197
# 700           0.21547591011823503
# 800           0.21547550175413516
# 900           0.21547532646096307
# 1000          0.21547581207431704
# 1100          0.21547527663133664
# 1200          0.21547575670441693
# 1300          0.21547574293438848
# 1400          0.21547522290044469
# 1500          0.21547520341502885

# %%
grafico("../../log/Virginica-Chi/c1_sigma05_penalization100.log")
tabella("../../log/Virginica-Chi/c1_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.06111573346105165
# 200           0.027865670213416127
# 300           0.012470697375818018
# 400           0.040116311085773904
# 500           0.03994678231680532
# 600           0.039981231561868724
# 700           0.039779565467910394
# 800           0.039863349962264205
# 900           0.03980736375177957
# 1000          0.03967202098028899
# 1100          0.039616301416619704
# 1200          0.03952418373956451
# 1300          0.03952309332931897
# 1400          0.03944099102181026
# 1500          0.03935052045262388

# %%
grafico("../../log/Virginica-Chi/c1_sigma025_penalization01.log")
tabella("../../log/Virginica-Chi/c1_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.05240263245548163
# 200           0.13561514618780066
# 300           0.15671698771477324
# 400           0.14434554856842804
# 500           0.13097240781073125
# 600           0.12171946267400993
# 700           0.11661041224773197
# 800           0.11852533945386531
# 900           0.1267601696734075
# 1000          0.10057625720998808
# 1100          0.0955348717585757
# 1200          0.09205407292347875
# 1300          0.11154507201246003
# 1400          0.10333693019123741
# 1500          0.10661954883909525

# %%
grafico("../../log/Virginica-Chi/c1_sigma025_penalization10.log")
tabella("../../log/Virginica-Chi/c1_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.24712790198410942
# 200           0.09006271751254538
# 300           0.1309753958914178
# 400           0.7714495729379639
# 500           0.3585802291328344
# 600           0.3585802257748838
# 700           0.20218438711050865
# 800           0.3585802055923387
# 900           0.3585800997963271
# 1000          0.35858008315104095
# 1100          0.3585801254780837
# 1200          0.3585803791739035
# 1300          0.3585803706182946
# 1400          0.3585800724408007
# 1500          0.19777241418903227

# %%
grafico("../../log/Virginica-Chi/c1_sigma025_penalization100.log")
tabella("../../log/Virginica-Chi/c1_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.23512840043876973
# 200           0.07878671829616882
# 300           0.16809912186986734
# 400           0.35858011375845
# 500           0.3585800378459023
# 600           0.3585801182618862
# 700           0.3585800073669032
# 800           0.358580301660708
# 900           0.3585800822270826
# 1000          0.35858029959642346
# 1100          0.35858007335336084
# 1200          0.3585800412205188
# 1300          0.35858004321589343
# 1400          0.35858004424287604
# 1500          0.35858004086239836

# %%
grafico("../../log/Virginica-Chi/c005_sigma01_penalization10.log")
tabella("../../log/Virginica-Chi/c005_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.4143401774991512
# 200           0.3109162056269217
# 300           0.5000010764155599
# 400           0.5000010025852747
# 500           0.5000007368900563
# 600           0.5000007306124509
# 700           0.5000010440578165
# 800           0.5000010414104166
# 900           0.5000010400511422
# 1000          0.5000008796225585
# 1100          0.5000010741954973
# 1200          0.5000010417461863
# 1300          0.5000007276208263
# 1400          0.5000009802906602
# 1500          0.5000010797302957

# %%
grafico("../../log/Virginica-Chi/c005_sigma01_penalization100.log")
tabella("../../log/Virginica-Chi/c005_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.305685527375413
# 200           0.3054198403924896
# 300           0.5000007464547336
# 400           0.5000007381614322
# 500           0.5000010556609317
# 600           0.500001043897136
# 700           0.5000010392757287
# 800           0.5000010364681672
# 900           0.5000008788734618
# 1000          0.5000009877656925
# 1100          0.5000010530228832
# 1200          0.5000010453241039
# 1300          0.5000010409692055
# 1400          0.5000007291313069
# 1500          0.5000009799846586

# %%
grafico("../../log/Virginica-Chi/c75_sigma01_penalization01.log")
tabella("../../log/Virginica-Chi/c75_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.29462306904585606
# 200           0.30318856712554154
# 300           0.31449318230543377
# 400           0.3119078585744239
# 500           0.3915779666014811
# 600           0.38809513518554356
# 700           0.29448105006601927
# 800           0.28946173068924114
# 900           0.2853016579825393
# 1000          0.26950337643613953
# 1100          0.23266703173122286
# 1200          0.15449199304749342
# 1300          0.15205226181635703
# 1400          0.15168222778543006
# 1500          0.15202656389405192

# %%
grafico("../../log/Virginica-Chi/c75_sigma01_penalization10.log")
tabella("../../log/Virginica-Chi/c75_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.44591934394478083
# 200           0.2623483890693063
# 300           0.5000009442964226
# 400           0.5000010377136946
# 500           0.50000091478015
# 600           0.5000010133273344
# 700           0.5000007479004271
# 800           0.5000010689078666
# 900           0.5000010968121786
# 1000          0.5000007403229428
# 1100          0.5000010575779295
# 1200          0.500000893407874
# 1300          0.5000010559246385
# 1400          0.5000010525470554
# 1500          0.5000007372510495

# %%
grafico("../../log/Virginica-Chi/c75_sigma01_penalization100.log")
tabella("../../log/Virginica-Chi/c75_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3866558339639195
# 200           0.5000008534572691
# 300           0.5000009830477924
# 400           0.500001023608969
# 500           0.5000008570016347
# 600           0.5000010345315665
# 700           0.5000007255046619
# 800           0.5000009805782967
# 900           0.5000010368920362
# 1000          0.5000010369656855
# 1100          0.5000010323758869
# 1200          0.5000008730737209
# 1300          0.5000010778709086
# 1400          0.5000009809349812
# 1500          0.5000009775680317

# %%
grafico("../../log/Virginica-Chi/c75_sigma025_penalization01.log")
tabella("../../log/Virginica-Chi/c75_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.09031032977637238
# 200           0.1508669464884231
# 300           0.1662705138226763
# 400           0.15286763602581196
# 500           0.13534426823821535
# 600           0.12774180745805705
# 700           0.13104713412989452
# 800           0.12517868207000896
# 900           0.11510674283043074
# 1000          0.10193945355311029
# 1100          0.10889306720189892
# 1200          0.09526744509993759
# 1300          0.09490228009372553
# 1400          0.10699814122070517
# 1500          0.08832655596925462

# %%
grafico("../../log/Virginica-Chi/c75_sigma025_penalization10.log")
tabella("../../log/Virginica-Chi/c75_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.15669811466912067
# 200           0.08632623193110395
# 300           0.16791749630449962
# 400           0.19827788547223826
# 500           0.19749462406687643
# 600           0.19741314029828075
# 700           0.26682693422655
# 800           0.358580064873559
# 900           0.3585802546236304
# 1000          0.3585800087798331
# 1100          0.3585799959114334
# 1200          0.35858004255052756
# 1300          0.358580226498069
# 1400          0.358580231362028
# 1500          0.35857997703869515

# %%
grafico("../../log/Virginica-Chi/c75_sigma025_penalization100.log")
tabella("../../log/Virginica-Chi/c75_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.21498979495737783
# 200           0.12370675776366799
# 300           0.19530017309215367
# 400           0.3585804218312594
# 500           0.3585803932834568
# 600           0.35858048206684556
# 700           0.35858048024366507
# 800           0.3585803687204344
# 900           0.3585803737318062
# 1000          0.3585803647824216
# 1100          0.3585804805401408
# 1200          0.3585804710369507
# 1300          0.35858046384168074
# 1400          0.358580367660284
# 1500          0.35858042519301037

# %%
grafico("../../log/Virginica-Chi/c75_sigma05_penalization01.log")
tabella("../../log/Virginica-Chi/c75_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.06381362698909931
# 200           0.10180730551209785
# 300           0.07078447505028793
# 400           0.01733784211709144
# 500           0.02828764750066215
# 600           0.022073351413798736
# 700           0.04380615328193138
# 800           0.025454319362643862
# 900           0.022391332404339048
# 1000          0.018332166420715224
# 1100          0.024322251050361843
# 1200          0.02974624979988666
# 1300          0.016831414697289437
# 1400          0.025191110036254183
# 1500          0.01945945100024815

# %%
grafico("../../log/Virginica-Chi/c75_sigma05_penalization10.log")
tabella("../../log/Virginica-Chi/c75_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.004235820338448992
# 200           0.060743561074283886
# 300           0.027722478102102044
# 400           0.0389399080410599
# 500           0.038229414748390755
# 600           0.03763703559600812
# 700           0.03684881817959679
# 800           0.036175661318104235
# 900           0.03549625302367432
# 1000          0.034785268965809635
# 1100          0.03425319671366239
# 1200          0.03337784829880441
# 1300          0.03273731346993397
# 1400          0.03197172402364218
# 1500          0.03126554725528108

# %%
grafico("../../log/Virginica-Chi/c75_sigma05_penalization100.log")
tabella("../../log/Virginica-Chi/c75_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.09561917252113389
# 200           0.017379778219041186
# 300           0.2154756059290756
# 400           0.21547540333937826
# 500           0.21547517623488638
# 600           0.21547526130727485
# 700           0.2154752907617679
# 800           0.21547527683970008
# 900           0.2154749467282519
# 1000          0.21547526591524685
# 1100          0.21547526253661914
# 1200          0.21547489542179538
# 1300          0.21547523457828727
# 1400          0.2154750368854939
# 1500          0.2154752212026016

# %%
grafico("../../log/Virginica-Chi/c200_sigma01_penalization01.log")
tabella("../../log/Virginica-Chi/c200_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3008144986136214
# 200           0.3005452198698821
# 300           0.50000286482002
# 400           0.8658340808770889
# 500           0.8658275802253984
# 600           0.8659854135397407
# 700           0.2954242585418267
# 800           0.2903060323981231
# 900           0.28734168138999144
# 1000          0.281310113592742
# 1100          0.23695421480200884
# 1200          0.15418939038915494
# 1300          0.1514319080087236
# 1400          0.15142443279851428
# 1500          0.1513543321786316

# %%
grafico("../../log/Virginica-Chi/c200_sigma01_penalization10.log")
tabella("../../log/Virginica-Chi/c200_sigma01_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.3548022967144102
# 200           0.3120562607138317
# 300           0.5000011053524873
# 400           0.5000010914216413
# 500           0.5000010746344459
# 600           0.5000010485719527
# 700           0.5000010380042902
# 800           0.5000009311518396
# 900           0.5000010938522772
# 1000          0.5000010887236761
# 1100          0.5000009120283626
# 1200          0.5000007512024788
# 1300          0.5000010112041696
# 1400          0.5000007504296204
# 1500          0.5000010834625871

# %%
grafico("../../log/Virginica-Chi/c200_sigma01_penalization100.log")
tabella("../../log/Virginica-Chi/c200_sigma01_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.2142472016886172
# 200           0.5000010343931078
# 300           0.500000736229542
# 400           0.500001058847334
# 500           0.5000008893576415
# 600           0.500001053279134
# 700           0.500000993133163
# 800           0.50000108767367
# 900           0.5000010885175132
# 1000          0.5000010574033107
# 1100          0.5000010940148952
# 1200          0.5000010881533888
# 1300          0.5000009962412219
# 1400          0.5000009922445581
# 1500          0.5000010560376014

# %%
grafico("../../log/Virginica-Chi/c200_sigma025_penalization01.log")
tabella("../../log/Virginica-Chi/c200_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.04554294465188061
# 200           0.1439464869626343
# 300           0.1557669072378366
# 400           0.14573918514657547
# 500           0.13184519427825342
# 600           0.12450454269995576
# 700           0.11767790666571298
# 800           0.12029939925131289
# 900           0.11419504869218755
# 1000          0.12156109868134801
# 1100          0.09563432589164314
# 1200          0.09181635937929877
# 1300          0.0916100835130747
# 1400          0.10250268058707915
# 1500          0.0920266733275849

# %%
grafico("../../log/Virginica-Chi/c200_sigma025_penalization10.log")
tabella("../../log/Virginica-Chi/c200_sigma025_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.16912714687699953
# 200           0.09246556421447324
# 300           0.1570237030928947
# 400           0.19506305429409232
# 500           0.19574990131985076
# 600           0.19550678936680965
# 700           0.19559838322097428
# 800           0.19559717589240228
# 900           0.19525786397454098
# 1000          0.19532747739454442
# 1100          0.19478700632976093
# 1200          0.19455201381846654
# 1300          0.19440185469931054
# 1400          0.1941047499610682
# 1500          0.19393790076622114

# %%
grafico("../../log/Virginica-Chi/c200_sigma025_penalization100.log")
tabella("../../log/Virginica-Chi/c200_sigma025_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.15542069831026722
# 200           0.09233310547102333
# 300           0.20510895530732165
# 400           0.35858029753024756
# 500           0.2180770161157382
# 600           0.764117157576429
# 700           0.35857992846921605
# 800           0.35858025922454473
# 900           0.3585802448363491
# 1000          0.3585799368217214
# 1100          0.35858013200762695
# 1200          0.3585801371178886
# 1300          0.35858011581690463
# 1400          0.3585799061482273
# 1500          0.3585802949702638

# %%
grafico("../../log/Virginica-Chi/c200_sigma05_penalization01.log")
tabella("../../log/Virginica-Chi/c200_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.07707423302366362
# 200           0.11214565804923773
# 300           0.12850805428891318
# 400           0.06626870335512558
# 500           0.040296918892298805
# 600           0.01695494802165537
# 700           0.0193861907346195
# 800           0.03686239676815062
# 900           0.036837003611107755
# 1000          0.03044190023544091
# 1100          0.031960349448146574
# 1200          0.028564931136965455
# 1300          0.03642318342632256
# 1400          0.027683655428827836
# 1500          0.01908646330659558

# %%
grafico("../../log/Virginica-Chi/c200_sigma05_penalization10.log")
tabella("../../log/Virginica-Chi/c200_sigma05_penalization10.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.12122783282320121
# 200           0.00882099663883773
# 300           0.026162212474543478
# 400           0.025179383132277522
# 500           0.024282629861148597
# 600           0.02344273460476881
# 700           0.02261977394188175
# 800           0.021806170560688676
# 900           0.021038216601286963
# 1000          0.02035858557668957
# 1100          0.01971623015524221
# 1200          0.0193717373085322
# 1300          0.018813610469618713
# 1400          0.0184741504854688
# 1500          0.018016127790769443

# %%
grafico("../../log/Virginica-Chi/c200_sigma05_penalization100.log")
tabella("../../log/Virginica-Chi/c200_sigma05_penalization100.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.025765968274450934
# 200           0.06545143505311266
# 300           0.014901316782844287
# 400           0.21547598006402036
# 500           0.21547582892156336
# 600           0.21547599915186044
# 700           0.21547598788813993
# 800           0.21547560277080224
# 900           0.21547558563882507
# 1000          0.21547572061293074
# 1100          0.21547590556764717
# 1200          0.21547590160866148
# 1300          0.21547578822122204
# 1400          0.21547577533183238
# 1500          0.21547568430721775
