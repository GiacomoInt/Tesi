# %%
import time
import datetime as dt

def epoch_to_millis(epoch):
    
    datetime_time = dt.datetime.fromtimestamp(epoch)
    s = (datetime_time - dt.datetime(1970, 1, 1)).total_seconds()-3600
               
    return s

# %%
#import e parsing file di log
import pandas as pd



def start(path):
    
    file = open(path, 'r')
    Lines = file.readlines()
    
    return Lines

def rmse_distance(Lines):
    
    coppie = []

    for line in Lines:
        
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))          
        
    return coppie


def execution_time_gurobi(Lines):
    
    for line in Lines:
        
        if 'TEMPO_ESECUZIONE GUROBI' in line:
            split = line.split(':')
            
    return epoch_to_millis(float(split[3]))
    
    
def execution_time_tensorflow(Lines):
    
    for line in Lines:
        if 'TEMPO_ESECUZIONE TENSORFLOW' in line:
            split = line.split(':')
            
    return epoch_to_millis(float(split[3]))

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def graph_rmse_distance(coppie):

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %%
#funzione per tabella

def tab_rmse_distance(coppie):
    
    print ("N_ITER        RMSE_DISTANCE")
    for i in coppie:
        print ("{:<14}{:<11}".format(*i))

# %% [markdown]
# ## Adam

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_Adam.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)

# %% [markdown]
# ### Prova Adadelta con learning rate superiore

# %% [markdown]
# ## Adadelta

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_Adadelta.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)

# %% [markdown]
# ## Adagrad

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_Adagrad.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)

# %% [markdown]
# ## Adamax

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_Adamax.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)

# %% [markdown]
# ## Ftrl

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_Ftrl.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)

# %% [markdown]
# ## Rms prop

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_RMSProp.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)

# %% [markdown]
# ## SGD

# %%
path = "../../../log/Prove-6/Different-Optimizer/Setosa_c1_sigma025_penalization01_SGD.log"

lines = start(path)
coppie = rmse_distance(lines)
graph_rmse_distance(coppie)
#tab_rmse_distance(coppie)
