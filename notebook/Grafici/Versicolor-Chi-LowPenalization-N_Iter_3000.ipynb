# %% [markdown]
# ### Codice

# %%
#import e parsing file di log

def lettura_log(path):

    file = open(path, 'r')
    Lines = file.readlines()

    coppie = []

    for line in Lines:
        if 'COUPLE(N_ITER,DISTANCE RMSE)' in line:
            split = line.split(':')
            s = split[3].replace('[','')
            s = s.replace('(','')
            s = s.replace(')','')
            s = s.replace(']','')
            s = s.split(',')
            a = int(s[0])
            b = float(s[1])
            coppie.append((a,b))

    return coppie

# %%
#funzione per graficare

import matplotlib.pyplot as plt

def grafico(path):

    coppie = lettura_log(path)

    x_val = [x[0] for x in coppie]
    y_val = [x[1] for x in coppie]

    fig, ax = plt.subplots(figsize=(10, 5))

    ax.plot(x_val,y_val)
    ax.plot(x_val,y_val,'or')

    ax.set_ylabel('RMSE Distance (Gurobi -TensorFlow)')
    ax.set_xlabel('Number of Iteration')

    return plt.show()

# %%
def tabella(path):

    coppie = lettura_log(path)
    
    print ("N_ITER        RMSE_DISTANCE")
    for i in coppie:
        print ("{:<14}{:<11}".format(*i))

# %% [markdown]
# # Versicolor

# %%
grafico("../../log/N_Iter_3000/Versicolor/c1_sigma01_penalization01.log")
tabella("../../log/N_Iter_3000/Versicolor/c1_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.37923332500866036
# 200           3.857906429980734e-08
# 300           0.16764881329728867
# 400           0.24898623749657686
# 500           0.8657814405021119
# 600           0.8657303747696777
# 700           0.8656631875501345
# 800           0.8656043103196334
# 900           0.8656830193643094
# 1000          0.8658902756264641
# 1100          0.8660164703072459
# 1200          0.5000043202724059
# 1300          0.2884591941545903
# 1400          0.2814400458769888
# 1500          0.2442030177668301
# 1600          0.12699672830565614
# 1700          0.12478453040618578
# 1800          0.12479749750832529
# 1900          0.12484609249610153
# 2000          0.1248595203959481
# 2100          0.1247800680197953
# 2200          0.12474431284815475
# 2300          0.12481610767137828
# 2400          0.12481757653593502
# 2500          0.12482159497398472
# 2600          0.12483410627169603
# 2700          0.12481167245846063
# 2800          0.1248363056212962
# 2900          0.12484237362738392
# 3000          0.12476830370776969

# %%
grafico("../../log/N_Iter_3000/Versicolor/c1_sigma025_penalization01.log")
tabella("../../log/N_Iter_3000/Versicolor/c1_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.030082441655167103
# 200           0.06850623946186887
# 300           0.0912892248317054
# 400           0.08915481058512212
# 500           0.084479092381781
# 600           0.062004136992035136
# 700           0.05187355090386528
# 800           0.0614025717742315
# 900           0.05156431583112844
# 1000          0.06773600134911259
# 1100          0.06575573665061843
# 1200          0.06644306955237408
# 1300          0.06183697199113122
# 1400          0.0608501828256697
# 1500          0.06121185089322603
# 1600          0.054141337718577126
# 1700          0.05846804750981485
# 1800          0.05943052365472043
# 1900          0.05952078810552522
# 2000          0.0552790145641022
# 2100          0.05300029099963896
# 2200          0.050622137810424656
# 2300          0.0667174268794142
# 2400          0.06376247687945011
# 2500          0.06003355738756269
# 2600          0.06701131106171734
# 2700          0.0637714114019802
# 2800          0.06673095193806175
# 2900          0.06211441367233453
# 3000          0.06248660673148429

# %%
grafico("../../log/N_Iter_3000/Versicolor/c1_sigma05_penalization01.log")
tabella("../../log/N_Iter_3000/Versicolor/c1_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0
# 1800          0.1325092223026138
# 1900          0.1276942049352542
# 2000          0.11895009550824245
# 2100          0.12465307192707847
# 2200          0.12692048997758976
# 2300          0.12923450769879966
# 2400          0.13242263617732203
# 2500          0.12031449787200146
# 2600          0.11435243425529729
# 2700          0.11590952918285141
# 2800          0.12405105225619062
# 2900          0.1287011832521527
# 3000          0.11412330602703233

# %%
grafico("../../log/N_Iter_3000/Versicolor/c200_sigma01_penalization01.log")
tabella("../../log/N_Iter_3000/Versicolor/c200_sigma01_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.27679876379873053
# 200           0.29179044581400676
# 300           0.865986352796483
# 400           0.8659739441965
# 500           0.8659519078383511
# 600           0.8659959628154992
# 700           0.5000039022826874
# 800           0.28966437303712267
# 900           0.28628734345437723
# 1000          0.25869520464757956
# 1100          0.1857063072595089
# 1200          0.12285403595276712
# 1300          0.12487479292921917
# 1400          0.1247711572038871
# 1500          0.12477136886306844
# 1600          0.12474164441611675
# 1700          0.12483258801122599
# 1800          0.12483199890210711
# 1900          0.12478827482315809
# 2000          0.12486721617803317
# 2100          0.12487371389358563
# 2200          0.12479683856767249
# 2300          0.12477320058364384
# 2400          0.12476884897354122
# 2500          0.12481699989520292
# 2600          0.12478240689853272
# 2700          0.12477814285520485
# 2800          0.12478145209339289
# 2900          0.12485194846561139
# 3000          0.1248367297120279

# %%
grafico("../../log/N_Iter_3000/Versicolor/c200_sigma025_penalization01.log")
tabella("../../log/N_Iter_3000/Versicolor/c200_sigma025_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.010610693232688595
# 200           0.06463151074105031
# 300           0.09127758411210105
# 400           0.07947113371497141
# 500           0.07089817387074185
# 600           0.06446908662198522
# 700           0.057347868534740526
# 800           0.06215952171697656
# 900           0.05084280279923001
# 1000          0.06237905318358053
# 1100          0.06449533149519235
# 1200          0.06188966676754323
# 1300          0.05907477965195282
# 1400          0.06036909368205398
# 1500          0.061230065710748044
# 1600          0.06120821274833274
# 1700          0.050628312077409504
# 1800          0.05531874241916565
# 1900          0.05413770635689971
# 2000          0.06708355287499976
# 2100          0.07020363027090779
# 2200          0.054133862257352866
# 2300          0.05907413375787554
# 2400          0.06356626159702153
# 2500          0.06673272182206777
# 2600          0.05301500807665191
# 2700          0.06624851992782912
# 2800          0.057007478727321065
# 2900          0.066119255720028
# 3000          0.06083314813772275

# %%
grafico("../../log/N_Iter_3000/Versicolor/c200_sigma05_penalization01.log")
tabella("../../log/N_Iter_3000/Versicolor/c200_sigma05_penalization01.log")
# Out:
# N_ITER        RMSE_DISTANCE
# 100           0.13985541966147738
# 200           0.1785546353978531
# 300           0.15329574414122635
# 400           0.13738669189743166
# 500           0.12413228294539902
# 600           0.11923824925580179
# 700           0.12036026170139438
# 800           0.12212147023004577
# 900           0.11831277726083048
# 1000          0.10933064220345176
# 1100          0.11614633115453207
# 1200          0.1224135495339918
# 1300          0.12415813193915945
# 1400          0.11855052569148655
# 1500          0.11774260946185486
# 1600          0.12802000414968645
# 1700          0.12187498733197968
# 1800          0.13543694161999073
# 1900          0.12849858677045145
# 2000          0.1256624206585034
# 2100          0.12998539055316338
# 2200          0.13861874228818402
# 2300          0.13536866861245916
# 2400          0.12386326726699456
# 2500          0.13454635578097657
# 2600          0.13314851200102673
# 2700          0.12114713540813313
# 2800          0.1139495267827966
# 2900          0.11229846852077385
# 3000          0.1320178876182724
